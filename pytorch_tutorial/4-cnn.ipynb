# %%
import torch.nn as nn
import torch

from torchvision.datasets import MNIST, CIFAR10
from torchvision import transforms
from torch.utils.data import DataLoader

# %%
train_data = CIFAR10(root='./data', train=True, download=True, transform=transforms.ToTensor())
test_data = CIFAR10(root='./data', train=False, download=True, transform=transforms.ToTensor())
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
from cnn.lenet import LeNet

device = "cuda"

model = LeNet().to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

train_loader = DataLoader(dataset=train_data, batch_size=512, num_workers=4, shuffle=True)
test_loader = DataLoader(dataset=test_data, batch_size=512, num_workers=4, shuffle=False)

# %%
for epoch in range(50):
    model.train()
    for idx, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        train_loss = loss_fn(outputs, labels)
        train_loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if (idx % 100 == 0): print(f"train_loss: {train_loss.detach()}")
    
    model.eval()
    val_loss = []
    correct = 0
    total = 0
    for idx, (images, labels) in enumerate(test_loader):
        images = images.to(device)
        labels = labels.to(device)
        with torch.no_grad():
            outputs = model(images)
        val_loss.append(loss_fn(outputs, labels))
        preds = outputs.argmax(dim=1)
        correct += torch.sum(preds == labels)
        total += labels.numel()

    print(f"valid_loss {sum(val_loss)/len(val_loss)}")
    print(f"Accuracy at epoch {epoch}: {float(correct) / total}")
# Out:
# train_loss: 88.04226684570312
# valid_loss 12.352807998657227
# Accuracy at epoch 0: 0.1489
# train_loss: 13.113635063171387
# valid_loss 7.946834087371826
# Accuracy at epoch 1: 0.1822
# train_loss: 7.945398330688477
# valid_loss 6.009341239929199
# Accuracy at epoch 2: 0.1957
# train_loss: 5.892982482910156
# valid_loss 4.7448320388793945
# Accuracy at epoch 3: 0.2015
# train_loss: 4.717031002044678
# valid_loss 3.7830111980438232
# Accuracy at epoch 4: 0.1975
# train_loss: 3.553194046020508
# valid_loss 2.380542755126953
# Accuracy at epoch 5: 0.1313
# train_loss: 2.405125617980957
# valid_loss 2.259138822555542
# Accuracy at epoch 6: 0.1631
# train_loss: 2.2017624378204346
# valid_loss 2.1767022609710693
# Accuracy at epoch 7: 0.1911
# train_loss: 2.1786787509918213
# valid_loss 2.111968755722046
# Accuracy at epoch 8: 0.2065
# train_loss: 2.12121844291687
# valid_loss 2.066876173019409
# Accuracy at epoch 9: 0.2191
# train_loss: 2.1193196773529053
# valid_loss 2.025075674057007
# Accuracy at epoch 10: 0.2339
# train_loss: 2.0308573246002197
# valid_loss 1.9845079183578491
# Accuracy at epoch 11: 0.2475
# train_loss: 1.913293719291687
# valid_loss 1.9464432001113892
# Accuracy at epoch 12: 0.2618
# train_loss: 1.915481448173523
# valid_loss 1.918836236000061
# Accuracy at epoch 13: 0.2664
# train_loss: 1.8806273937225342
# valid_loss 1.8879270553588867
# Accuracy at epoch 14: 0.2768
# train_loss: 1.88040030002594
# valid_loss 1.863294243812561
# Accuracy at epoch 15: 0.2904
# train_loss: 1.8694688081741333
# valid_loss 1.8427517414093018
# Accuracy at epoch 16: 0.2951
# train_loss: 1.8307974338531494
# valid_loss 1.828734040260315
# Accuracy at epoch 17: 0.2979
# train_loss: 1.7692275047302246
# valid_loss 1.810803771018982
# Accuracy at epoch 18: 0.3082
# train_loss: 1.7789348363876343
# valid_loss 1.7993717193603516
# Accuracy at epoch 19: 0.3135
# train_loss: 1.729056477546692
# valid_loss 1.7888282537460327
# Accuracy at epoch 20: 0.324
# train_loss: 1.7689626216888428
# valid_loss 1.775613784790039
# Accuracy at epoch 21: 0.326
# train_loss: 1.7562155723571777
# valid_loss 1.764299988746643
# Accuracy at epoch 22: 0.3312
# train_loss: 1.7225748300552368
# valid_loss 1.7549364566802979
# Accuracy at epoch 23: 0.3425
# train_loss: 1.722475290298462
# valid_loss 1.748887300491333
# Accuracy at epoch 24: 0.3462
# train_loss: 1.75328528881073
# valid_loss 1.7399952411651611
# Accuracy at epoch 25: 0.349
# train_loss: 1.6836239099502563
# valid_loss 1.728255271911621
# Accuracy at epoch 26: 0.3523
# train_loss: 1.7712616920471191
# valid_loss 1.7223974466323853
# Accuracy at epoch 27: 0.3557
# train_loss: 1.6809114217758179
# valid_loss 1.7104190587997437
# Accuracy at epoch 28: 0.3608
# train_loss: 1.6209850311279297
# valid_loss 1.7036516666412354
# Accuracy at epoch 29: 0.3635
# train_loss: 1.6420965194702148
# valid_loss 1.69701087474823
# Accuracy at epoch 30: 0.3634
# train_loss: 1.6390516757965088
# valid_loss 1.6961519718170166
# Accuracy at epoch 31: 0.3722
# train_loss: 1.6000254154205322
# valid_loss 1.688458800315857
# Accuracy at epoch 32: 0.3694
# train_loss: 1.6415200233459473
# valid_loss 1.6768255233764648
# Accuracy at epoch 33: 0.3761
# train_loss: 1.673904538154602
# valid_loss 1.6692380905151367
# Accuracy at epoch 34: 0.3797
# train_loss: 1.6867910623550415
# valid_loss 1.6618260145187378
# Accuracy at epoch 35: 0.3823
# train_loss: 1.5857877731323242
# valid_loss 1.6560354232788086
# Accuracy at epoch 36: 0.3807
# train_loss: 1.5365229845046997
# valid_loss 1.6488336324691772
# Accuracy at epoch 37: 0.3884
# train_loss: 1.5657265186309814
# valid_loss 1.6355469226837158
# Accuracy at epoch 38: 0.3908
# train_loss: 1.4742655754089355
# valid_loss 1.6308149099349976
# Accuracy at epoch 39: 0.3958
# train_loss: 1.4599848985671997
# valid_loss 1.6207056045532227
# Accuracy at epoch 40: 0.4003
# train_loss: 1.5619090795516968
# valid_loss 1.6195942163467407
# Accuracy at epoch 41: 0.4034
# train_loss: 1.4700040817260742
# valid_loss 1.6082515716552734
# Accuracy at epoch 42: 0.4053
# train_loss: 1.5364042520523071
# valid_loss 1.606539011001587
# Accuracy at epoch 43: 0.4047
# train_loss: 1.5018967390060425
# valid_loss 1.6033414602279663
# Accuracy at epoch 44: 0.4087
# train_loss: 1.4026461839675903
# valid_loss 1.5892422199249268
# Accuracy at epoch 45: 0.4126
# train_loss: 1.512716293334961
# valid_loss 1.5820871591567993
# Accuracy at epoch 46: 0.4161
# train_loss: 1.495745062828064
# valid_loss 1.5779821872711182
# Accuracy at epoch 47: 0.4183
# train_loss: 1.4308269023895264
# valid_loss 1.5733027458190918
# Accuracy at epoch 48: 0.4238
# train_loss: 1.3837225437164307
# valid_loss 1.5653934478759766
# Accuracy at epoch 49: 0.4224

# %%
from cnn.resnet import Resnet

device = "cuda"

model = Resnet().to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)


for epoch in range(50):
    model.train()
    for idx, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        train_loss = loss_fn(outputs, labels)
        train_loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if (idx % 100 == 0): print(f"train_loss: {train_loss.detach()}")
    
    model.eval()
    val_loss = []
    correct = 0
    total = 0
    for idx, (images, labels) in enumerate(test_loader):
        images = images.to(device)
        labels = labels.to(device)
        with torch.no_grad():
            outputs = model(images)
        val_loss.append(loss_fn(outputs, labels))
        preds = outputs.argmax(dim=1)
        correct += torch.sum(preds == labels)
        total += labels.numel()

    print(f"valid_loss {sum(val_loss)/len(val_loss)}")
    print(f"Accuracy at epoch {epoch}: {float(correct) / total}")
# Out:
# train_loss: 2.300717830657959
# valid_loss 1.8408879041671753
# Accuracy at epoch 0: 0.3151
# train_loss: 1.8510942459106445
# valid_loss 1.7852483987808228
# Accuracy at epoch 1: 0.3412
# train_loss: 1.778308391571045
# valid_loss 1.6760081052780151
# Accuracy at epoch 2: 0.3705
# train_loss: 1.7152762413024902
# valid_loss 1.6063851118087769
# Accuracy at epoch 3: 0.3999
# train_loss: 1.626475214958191
# valid_loss 1.547011375427246
# Accuracy at epoch 4: 0.418
# train_loss: 1.5863898992538452
# valid_loss 1.5071254968643188
# Accuracy at epoch 5: 0.4419
# train_loss: 1.4765350818634033
# valid_loss 1.4901087284088135
# Accuracy at epoch 6: 0.4463
# train_loss: 1.4317840337753296
# valid_loss 1.4406628608703613
# Accuracy at epoch 7: 0.4635
# train_loss: 1.4884535074234009
# valid_loss 1.4108012914657593
# Accuracy at epoch 8: 0.4766
# train_loss: 1.4024845361709595
# valid_loss 1.4139561653137207
# Accuracy at epoch 9: 0.4825
# train_loss: 1.3922823667526245
# valid_loss 1.3438633680343628
# Accuracy at epoch 10: 0.5043
# train_loss: 1.3088120222091675
# valid_loss 1.367008090019226
# Accuracy at epoch 11: 0.504
# train_loss: 1.4109854698181152
# valid_loss 1.297451376914978
# Accuracy at epoch 12: 0.5248
# train_loss: 1.2264316082000732
# valid_loss 1.2837532758712769
# Accuracy at epoch 13: 0.5385
# train_loss: 1.3050347566604614
# valid_loss 1.2382762432098389
# Accuracy at epoch 14: 0.5538
# train_loss: 1.1576348543167114
# valid_loss 1.2232290506362915
# Accuracy at epoch 15: 0.5553
# train_loss: 1.1943267583847046
# valid_loss 1.2052371501922607
# Accuracy at epoch 16: 0.5669
# train_loss: 1.138757348060608
# valid_loss 1.1926324367523193
# Accuracy at epoch 17: 0.5694
# train_loss: 1.1028995513916016
# valid_loss 1.1878232955932617
# Accuracy at epoch 18: 0.5735
# train_loss: 1.192002534866333
# valid_loss 1.1492387056350708
# Accuracy at epoch 19: 0.5873
# train_loss: 1.09181809425354
# valid_loss 1.194114089012146
# Accuracy at epoch 20: 0.5651
# train_loss: 1.1552473306655884
# valid_loss 1.2195698022842407
# Accuracy at epoch 21: 0.5585
# train_loss: 1.2244964838027954
# valid_loss 1.1632330417633057
# Accuracy at epoch 22: 0.5773
# train_loss: 1.1336884498596191
# valid_loss 1.1050702333450317
# Accuracy at epoch 23: 0.6027
# train_loss: 1.040467619895935
# valid_loss 1.129497766494751
# Accuracy at epoch 24: 0.5979
# train_loss: 0.994189441204071
# valid_loss 1.1027783155441284
# Accuracy at epoch 25: 0.6063
# train_loss: 1.0866377353668213
# valid_loss 1.0766724348068237
# Accuracy at epoch 26: 0.6139
# train_loss: 1.0203068256378174
# valid_loss 1.071771264076233
# Accuracy at epoch 27: 0.6133
# train_loss: 1.0074204206466675
# valid_loss 1.0858360528945923
# Accuracy at epoch 28: 0.6118
# train_loss: 1.0375330448150635
# valid_loss 1.0598251819610596
# Accuracy at epoch 29: 0.6204
# train_loss: 0.9617278575897217
# valid_loss 1.0736823081970215
# Accuracy at epoch 30: 0.6191
# train_loss: 1.0362831354141235
# valid_loss 1.044019341468811
# Accuracy at epoch 31: 0.6238
# train_loss: 1.0002284049987793
# valid_loss 1.0309816598892212
# Accuracy at epoch 32: 0.6313
# train_loss: 0.9045577645301819
# valid_loss 1.0512583255767822
# Accuracy at epoch 33: 0.6191
# train_loss: 0.8677984476089478
# valid_loss 1.055091142654419
# Accuracy at epoch 34: 0.6202
# train_loss: 0.9797213673591614
# valid_loss 1.029016137123108
# Accuracy at epoch 35: 0.6301
# train_loss: 0.9631310105323792
# valid_loss 1.0154695510864258
# Accuracy at epoch 36: 0.6367
# train_loss: 0.9598228931427002
# valid_loss 0.9907506108283997
# Accuracy at epoch 37: 0.6402
# train_loss: 0.9126052260398865
# valid_loss 1.0104906558990479
# Accuracy at epoch 38: 0.6362
# train_loss: 0.9464606046676636
# valid_loss 1.0254476070404053
# Accuracy at epoch 39: 0.6282
# train_loss: 0.9719734191894531
# valid_loss 0.9723698496818542
# Accuracy at epoch 40: 0.6523
# train_loss: 0.8861437439918518
# valid_loss 1.0042879581451416
# Accuracy at epoch 41: 0.6428
# train_loss: 0.9788582921028137
# valid_loss 0.9953585863113403
# Accuracy at epoch 42: 0.647
# train_loss: 0.851754367351532
# valid_loss 0.9692453742027283
# Accuracy at epoch 43: 0.6574
# train_loss: 0.8620750308036804
# valid_loss 0.9543717503547668
# Accuracy at epoch 44: 0.6585
# train_loss: 0.9238035082817078
# valid_loss 0.9629833102226257
# Accuracy at epoch 45: 0.6575
# train_loss: 0.8637059926986694
# valid_loss 0.9597060084342957
# Accuracy at epoch 46: 0.6611
# train_loss: 0.8417056798934937
# valid_loss 0.9627999663352966
# Accuracy at epoch 47: 0.6587
# train_loss: 0.768416702747345
# valid_loss 0.9470266699790955
# Accuracy at epoch 48: 0.6619
# train_loss: 0.8032804131507874
# valid_loss 0.9096218943595886
# Accuracy at epoch 49: 0.6757

# %%
from torchvision import models

models.resnet152
