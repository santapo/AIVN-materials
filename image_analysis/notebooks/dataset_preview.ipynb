# %%
import os
import glob
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataset_path = "/root/splitted_flowers/valid"

all_data = glob.glob(os.path.join(dataset_path, "*", "*"))
total_samples = len(all_data)
print(f"total_samples: {total_samples}")
# Out:
# total_samples: 1296

# %%
from torchvision.datasets import ImageFolder
dataset = ImageFolder(root=dataset_path)
image_path, image_label = zip(*dataset.samples)

# %%
data_info = {}

for c in glob.glob(os.path.join(dataset_path, "*")):
    class_name = os.path.basename(c)
    samples = glob.glob(os.path.join(c, "*"))
    data_info[class_name] = len(samples)

# %%
data_info
# Out:
# {'dandelion': 739, 'sunflower': 495, 'rose': 543, 'daisy': 539, 'tulip': 705}

# %%
num_sample
# Out:
# [739.0, 495.0, 543.0, 539.0, 705.0]

# %%
num_sample = [float(i) for i in data_info.values()]
sns.barplot(x=list(data_info.keys()), y=num_sample)
# Out:
# <AxesSubplot:>

# %%
classes = ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']
num_classes = len(classes)
samples_per_class = 7
plt.figure(figsize=(20, 20))
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(np.array(image_label) == y)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(dataset[idx][0])
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()

# %%
dataset[idx][0]
# Out:
# <PIL.Image.Image image mode=RGB size=240x240 at 0x7FE009B8B820>
