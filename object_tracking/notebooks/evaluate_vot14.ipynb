# %%
# %cd ..

from dataset import VOT14Reader
from evaluate_vot14 import VOT14Evaluator
from trackers import ColorMSTracker
# Out:
# /Users/santapo/Works/AIVN/AIVN-materials/object_tracking

# %%
dataset = VOT14Reader(dataset_path="./vot14")
evaluator = VOT14Evaluator(dataset)
# tracker = ColorMSTracker

evaluator.set_tracker("meanshift", ColorMSTracker)

# %%
for i in range(len(dataset)):
    # print(dataset[i][2][1])
    evaluator.evaluate_by_index("meanshift", i)

for i in range(len(dataset)):
    evaluator.draw_iou_record(i, 0)
# Out:
# Evaluating: 282it [00:00, 41981.75it/s]
# Evaluating: 400it [00:00, 23806.59it/s]
# Evaluating: 252it [00:00, 44919.87it/s]
# Evaluating: 310it [00:00, 23072.62it/s]
# Evaluating: 264it [00:00, 30622.98it/s]
# Evaluating: 207it [00:00, 24313.10it/s]
# Evaluating: 267it [00:00, 34590.86it/s]
# Evaluating: 172it [00:00, 45781.21it/s]
# Evaluating: 350it [00:00, 25257.76it/s]
# Evaluating: 201it [00:00, 4511.69it/s]
# Evaluating: 725it [00:00, 29737.53it/s]
# Evaluating: 731it [00:00, 37797.24it/s]
# Evaluating: 770it [00:00, 18876.26it/s]
# Evaluating: 602it [00:00, 12075.94it/s]
# Evaluating: 436it [00:00, 24256.11it/s]
# Evaluating: 244it [00:00, 23491.03it/s]
# Evaluating: 292it [00:00, 25568.62it/s]
# Evaluating: 219it [00:00, 44306.03it/s]
# Evaluating: 307it [00:00, 46193.77it/s]
# Evaluating: 371it [00:00, 8275.74it/s]
# Evaluating: 271it [00:00, 36478.06it/s]
# Evaluating: 1210it [00:00, 34144.08it/s]
# Evaluating: 164it [00:00, 17297.84it/s]
# Evaluating: 569it [00:00, 31351.35it/s]
# Evaluating: 597it [00:00, 38191.10it/s]
# /Users/santapo/Works/AIVN/AIVN-materials/object_tracking/evaluate_vot14.py:120: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=(24, 6))
